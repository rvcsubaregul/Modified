# %%
# @title Run the `AICoverGen` App
import codecs

repo_base = codecs.decode("uggcf://tvguho.pbz/E3tz/NVPbireTra","rot_13")
folder_base = "app_acg"
conf_end = f"/content/{folder_base}/.venv/complete.txt"

def config_complete() -> bool:
    import os
    return os.path.exists(conf_end)

if not config_complete():
    print("\033[34mThe installation will take approximately 7 minutes.\033[0m")
    # %cd /content
    # !git clone {repo_base} {folder_base}  > /dev/null 2>&1
    # %cd {folder_base}
    # !xargs -r -a packages.txt apt install -y > /dev/null 2>&1
    # !pip install uv==0.8.13 > /dev/null 2>&1
    # !uv venv --python 3.10 --clear > /dev/null 2>&1
    # !curl -sS https://bootstrap.pypa.io/get-pip.py -o get-pip.py > /dev/null 2>&1
    # !uv run python get-pip.py pip==23.1.2 -> /dev/null 2>&1
    # !uv run python -m pip install -r pre-requirements.txt > /dev/null 2>&1
    # !uv run python -m pip install  torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124 > /dev/null 2>&1
    # !uv run python -m pip install -r requirements.txt && touch {conf_end} > /dev/null 2>&1

Use_the_builtin_audio_player = False #@param {type:"boolean"}
biplayer = '--builtin-player' if Use_the_builtin_audio_player else ''
Server_Side_Rendering = False #@param {type:"boolean"}
ssr = '--ssr' if Server_Side_Rendering else ''
Theme = "base" #@param {type:"string"}

# %cd /content/{folder_base}
# !uv run python app.py --share --theme {Theme} {ssr} {biplayer}

# %% [markdown]
# Open the `public URL` when it appears
